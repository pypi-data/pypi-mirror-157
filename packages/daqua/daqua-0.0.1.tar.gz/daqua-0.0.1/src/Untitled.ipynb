# %%
import numpy as np

# %%
import pandas as pd

# %%
d = [1,2,3]
{i: i**2 for i in d}
# Out:
# {1: 1, 2: 4, 3: 9}

# %%
path = r"/home/satya/Desktop/Personal/Workspace/Data Quality/data/PRM360 Data.xlsx"

# %%
df = pd.ExcelFile(path)

# %%
df.sheet_names
# Out:
# ['User',
#  'userdata',
#  'userroles',
#  'userverification',
#  'company',
#  'vendors',
#  'PR DETAILS',
#  'PR ITEMS',
#  'PO DETAILS',
#  'GRN details',
#  'Requirementdetails',
#  'Requirement items',
#  'Quotations',
#  'auction details',
#  'Negotiation Audit',
#  'auctiondetails_audit']

# %%
df.parse('User')
# Out:
#        U_ID  U_GENDER                          U_FNAME     U_LNAME  \
# 0     12734       NaN                       Automation    Customer
# 1     12735       NaN                       Automation     Subuser
# 2     12736       NaN                            PRICE         CAP
# 3     12737       NaN     SRIKAR LABORATORIES PVT LTD          NaN
# 4     12738       NaN  ACTIS GENERICS PRIVATE LIMITED          NaN
# ...     ...       ...                              ...         ...
# 3974  16742       NaN                        subuserqa   subuserqa
# 3975  16743       NaN                       subuserdev  subuserdev
# 3976  16744       NaN                        userkrish   userkrish
# 3977  16745       NaN                        venkatesh       penti
# 3978  16746       NaN                            Gouse       Shaik
#
#                                  U_EMAIL     U_PHONE  U_ALTPHONE  U_BIRTHDATE  \
# 0     sivakrishna_kalvagadda@hotmail.com  9866227863         NaN          NaN
# ...

# %%
import magic
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_10826/3567826855.py in <module>
# ----> 1 import magic
#
# ModuleNotFoundError: No module named 'magic'

# %%
class ReadFlatFile:
    """
    This is the super class to read all the flat files
    """
    def __init__(self, main):
        self.main = main
        self.file_path = self.main.config.file_name
        self.file_types = ['csv', 'excel', 'json']
        _,self.fileExtension = os.path.splitext(self.file_name)
        self.file_size = str(os.path.getsize(self.file_path)/(1024*1024)) + ' MB'


class ReadExcel(ReadFlatFile):
    def __init__(self, main):
        super().__init__(main)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_29616/2235834010.py in <module>
# ----> 1 excel = ReadExcel('a')
#
# /tmp/ipykernel_29616/1113945993.py in __init__(self, main)
#      13 class ReadExcel(ReadFlatFile):
#      14     def __init__(self, main):
# ---> 15         super().__init__(main)
#
# /tmp/ipykernel_29616/1113945993.py in __init__(self, main)
#       5     def __init__(self, main):
#       6         self.main = main
# ----> 7         self.file_path = self.main.config.file_name
#       8         self.file_types = ['csv', 'excel', 'json']
#       9         _,self.fileExtension = os.path.splitext(self.file_name)
#
# AttributeError: 'str' object has no attribute 'config'
